# %%
import matplotlib.pyplot as plt

# %%
names = ['20211129','20211130','20211201','20211202','20211203','20211209','20211210','20211211','20211212','20211213','20211214','20211215']
values = [123865236,162488930,198808643,239038312,314577759,655048436,639812132,497985867,92274552,279954418,233050936,225090064]
plt.figure(figsize=(50, 5))

plt.subplot(131)
plt.bar(names, values)
plt.ylabel('orc file sizes sum',  fontsize=60) 
plt.title("Stanger", fontsize=100, position=(0.5, 0.6))
plt.xticks(rotation=90)
plt.rcParams.update({'font.size': 50})
